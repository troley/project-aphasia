# %%
corrupt_file = '/datb/aphasia/languagedata/uva/transform/uniquewordfile/new_dict'
new_clean_file = '/datb/aphasia/languagedata/uva/transform/uniquewordfile/clean_dict'

with open (corrupt_file, 'r') as corrupt_file:
    words = corrupt_file.readlines()
    print ("Amount of lines in corrupt file: " + str(len(words)))
    
    i = 0
    while (i < 25):
        # Print a sample of the corrupt lines
        print(words[i])
        i += 1
    
    print("------- FILE DISTINCTION PRINT STATEMENT -------")
    with open (new_clean_file, 'w') as new_clean_file:
        for index, word in enumerate(words):
            if word is not "" and word is not "\n":
                if (index < 25):
                    print(word)
                new_clean_file.write(word)
# Out:
# Amount of lines in corrupt file: 6442
#
#
# zeiltocht
#
#
#
# kleinere
#
# Bergen
#
# souveniers
#
# sgaa
#
# oehoe
#
# vakblad
#
# reizen
#
# ouders
#
# gekocht
#
# apartement
#
# gezongen
#
# precies
#
#
#
# heb:
#
# overdag
#
# hebriden
#
#
#
# nadat
#
# kinderen
#
# ligt
#
# allemaal
#
#
#
# ------- FILE DISTINCTION PRINT STATEMENT -------
# zeiltocht
#
# kleinere
#
# Bergen
#
# souveniers
#
# sgaa
#
# oehoe
#
# vakblad
#
# reizen
#
# ouders
#
# gekocht
#
# apartement
#
# gezongen
#
# precies
#
# heb:
#
# overdag
#
# hebriden
#
# nadat
#
# kinderen
#
# ligt
#
# allemaal
